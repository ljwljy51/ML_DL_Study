# %% [markdown]
# # Inpainting
# - **random** sampling
# - probability **50%**
#
# # Learning type
# - residual
#
# # Network
# - UNet
# - ResNet

# %%
# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "train" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/unet/inpainting" \
--log_dir "/content/drive/MyDrive/SRResNet/log/unet/inpainting" \
--result_dir "/content/drive/MyDrive/SRResNet/result/unet/inpainting" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"

# %%
# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "train" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/resnet/inpainting" \
--log_dir "/content/drive/MyDrive/SRResNet/log/resnet/inpainting" \
--result_dir "/content/drive/MyDrive/SRResNet/result/resnet/inpainting" \
--network "resnet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"
