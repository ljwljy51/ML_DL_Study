# %% [markdown]
# # Super resolution
# - **bilinear** interpolation
# - **x4** downsampling
#
# # Learning type
# - plain
# - residual
#
# # Network
# - ResNet
# - SRResNet

# %%
# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "train" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/resnet/super_resolution" \
--log_dir "/content/drive/MyDrive/SRResNet/log/resnet/super_resolution" \
--result_dir "/content/drive/MyDrive/SRResNet/result/resnet/super_resolution" \
--network "resnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "test" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/resnet/super_resolution" \
--log_dir "/content/drive/MyDrive/SRResNet/log/resnet/super_resolution" \
--result_dir "/content/drive/MyDrive/SRResNet/result/resnet/super_resolution" \
--network "resnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
#input size가 작기 때문에 훨씬 빠르게 수행되는 것을 알 수 있음

# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "train" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/srresnet/super_resolution" \
--log_dir "/content/drive/MyDrive/SRResNet/log/srresnet/super_resolution" \
--result_dir "/content/drive/MyDrive/SRResNet/result/srresnet/super_resolution" \
--network "srresnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 0 \
--learning_type "residual"

# %%
# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "test" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/srresnet/super_resolution" \
--log_dir "/content/drive/MyDrive/SRResNet/log/srresnet/super_resolution" \
--result_dir "/content/drive/MyDrive/SRResNet/result/srresnet/super_resolution" \
--network "srresnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 0 \
--learning_type "residual"
