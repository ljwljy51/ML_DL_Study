# %% [markdown]
# # Denoising
# - **random** noise
# - sigma **30.0**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet
# - ResNet

# %%
# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "train" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/unet/denoising" \
--log_dir "/content/drive/MyDrive/SRResNet/log/unet/denoising" \
--result_dir "/content/drive/MyDrive/SRResNet/result/unet/denoising" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %%
# !python "/content/drive/MyDrive/SRResNet/train.py" \
--mode "train" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/MyDrive/SRResNet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/SRResNet/checkpoint/resnet/denoising" \
--log_dir "/content/drive/MyDrive/SRResNet/log/resnet/denoising" \
--result_dir "/content/drive/MyDrive/SRResNet/result/resnet/denoising" \
--network "resnet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"
