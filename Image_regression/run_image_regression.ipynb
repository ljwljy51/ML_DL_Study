# %% [markdown]
# # Inpainting
# - **random** sampling
# - probability **50%**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/inpainting/plain" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/inpainting/plain" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/inpainting/plain" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "test" \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/inpainting/plain" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/inpainting/plain" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/inpainting/plain/test" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "train" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/inpainting/residual" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/inpainting/residual" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/inpainting/residual" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "test" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/inpainting/residual" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/inpainting/residual" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/inpainting/residual/test" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"

# %% [markdown]
# # Denoising
# - **random** noise
# - sigma **30.0**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "train" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/denoising/plain" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/denoising/plain" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/denoising/plain" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "test" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/denoising/plain" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/denoising/plain" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/denoising/plain/test" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "train" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/denoising/residual" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/denoising/residual" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/denoising/residual" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "test" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/denoising/residual" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/denoising/residual" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/denoising/residual/test" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %% [markdown]
# # Super resolution
# - **bilinear** interpolation
# - **x4** downsampling
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "train" \
--train_continue "on" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/super_resolution/plain" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/super_resolution/plain" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/super_resolution/plain" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "test" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/super_resolution/plain" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/super_resolution/plain" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/super_resolution/plain/test" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "train" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/super_resolution/residual" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/super_resolution/residual" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/super_resolution/residual" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
# !python "/content/drive/MyDrive/UNet_pytorch_regression/train.py" \
--mode "test" \
--num_epoch 40 \
--data_dir "/content/drive/MyDrive/UNet_pytorch_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/UNet_pytorch_regression/checkpoint/super_resolution/residual" \
--log_dir "/content/drive/MyDrive/UNet_pytorch_regression/log/super_resolution/residual" \
--result_dir "/content/drive/MyDrive/UNet_pytorch_regression/result/super_resolution/residual/test" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir "/content/drive/MyDrive/UNet_pytorch_regression/log"
